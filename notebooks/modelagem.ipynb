# %% [markdown]
# <a href="https://colab.research.google.com/github/jggoncalez/cardiovascular-diseases-AI/blob/main/notebooks/modelagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modelagem — Doenças Cardiovasculares
#
# Este notebook realiza o **pré-processamento**, o **treinamento**
# e a **avaliação** dos modelos de Machine Learning aplicados ao
# dataset de doenças cardiovasculares.
#
# O objetivo é treinar e comparar diferentes algoritmos para
# prever o diagnóstico de doença cardíaca em pacientes, com base
# em variáveis clínicas como idade, pressão arterial, colesterol
# e frequência cardíaca máxima.
#
# ### O que você vai encontrar aqui:
# - Pré-processamento e normalização dos dados
# - Treinamento de 6 modelos de classificação
# - Avaliação com métricas de desempenho
# - Comparação final entre os modelos
# - Conclusão sobre o melhor algoritmo para o problema

# %% [markdown]
# ### Setup Inicial

# %%
url = "https://raw.githubusercontent.com/jggoncalez/cardiovascular-diseases-AI/main/data/Cardiovascular_Disease_Dataset.csv"

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# aif360                  0.6.1
# asttokens               3.0.1
# blinker                 1.9.0
# click                   8.3.0
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.20
# decorator               5.2.1
# executing               2.2.1
# Flask                   3.1.2
# fonttools               4.61.1
# future                  1.0.0
# ipykernel               7.2.0
# ipython                 9.10.0
# ipython_pygments_lexers 1.1.1
# iso8601                 2.1.0
# itsdangerous            2.2.0
# jedi                    0.19.2
# Jinja2                  3.1.6
# joblib                  1.5.3
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# kiwisolver              1.4.9
# MarkupSafe              3.0.3
# matplotlib              3.10.8
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# numpy                   2.4.2
# packaging               26.0
# pandas                  3.0.1
# parso                   0.8.6
# pillow                  12.1.1
# pip                     26.0.1
# platformdirs            4.9.2
# prompt_toolkit          3.0.52
# psutil                  7.2.2
# pure_eval               0.2.3
# Pygments                2.19.2
# pyparsing               3.3.2
# pyserial                3.5
# python-dateutil         2.9.0.post0
# PyYAML                  6.0.3
# pyzmq                   27.1.0
# scikit-learn            1.8.0
# scipy                   1.17.0
# seaborn                 0.13.2
# serial                  0.0.97
# six                     1.17.0
# stack-data              0.6.3
# threadpoolctl           3.6.0
# tornado                 6.5.4
# traitlets               5.14.3
# tzdata                  2025.3
# wcwidth                 0.6.0
# Werkzeug                3.1.3
# xgboost                 3.2.0

# %%
# !pip install numpy pandas matplotlib seaborn xgboost scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (2.4.2)
# Requirement already satisfied: pandas in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (3.0.1)
# Requirement already satisfied: matplotlib in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (3.10.8)
# Requirement already satisfied: seaborn in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (0.13.2)
# Requirement already satisfied: xgboost in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (3.2.0)
# Requirement already satisfied: scikit-learn in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from xgboost) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in C:\Users\kayqu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\kayqu\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import (
    accuracy_score, precision_score,
    recall_score, f1_score,
    roc_auc_score, ConfusionMatrixDisplay,
    classification_report
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

data = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ### Pré-processamento

# %% [markdown]
# #### Verificações

# %%
# Verifica se há valores nulos (iguais a 0)
print(data.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Verifica se há valores nulos (iguais a 0)
# ----> 2 print(data.isnull().sum())
#
# NameError: name 'data' is not defined

# %%
# Verifica o tipo de dado de cada coluna
print(data.dtypes)
# Out:
# patientid              int64
# age                    int64
# gender                 int64
# chestpain              int64
# restingBP              int64
# serumcholestrol        int64
# fastingbloodsugar      int64
# restingrelectro        int64
# maxheartrate           int64
# exerciseangia          int64
# oldpeak              float64
# slope                  int64
# noofmajorvessels       int64
# target                 int64
# dtype: object

# %% [markdown]
# #### Preparação dos dados

# %%
# Separa X e y
X = data.drop('target', axis=1)
y = data['target']

# Normaliza
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Divide treino e teste (train-test split)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Saída para teste
print(f'Treino: {X_train.shape[0]} pacientes')
print(f'Teste:  {X_test.shape[0]} pacientes')
# Out:
# Treino: 800 pacientes
# Teste:  200 pacientes

# %% [markdown]
# ### Treinamento

# %%
modelos = {
    'Logistic Regression': LogisticRegression(),
    'SGD Classifier':      SGDClassifier(),
    'SVM':                 SVC(probability=True),
    'Decision Tree':       DecisionTreeClassifier(),
    'AdaBoost':            AdaBoostClassifier(),
    'XGBoost':             xgb.XGBClassifier()
}

for nome, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    print(f'{nome} treinado')
# Out:
# Logistic Regression treinado
# SGD Classifier treinado
# SVM treinado
# Decision Tree treinado
# AdaBoost treinado
# XGBoost treinado

# %% [markdown]
# ### Avaliação com Métricas

# %%
resultados = []

for nome, modelo in modelos.items():
    y_pred = modelo.predict(X_test)

    resultados.append({
        'Modelo':    nome,
        'Acurácia':  accuracy_score(y_test, y_pred),
        'Precisão':  precision_score(y_test, y_pred),
        'Recall':    recall_score(y_test, y_pred),
        'F1-Score':  f1_score(y_test, y_pred),
        'ROC-AUC':   roc_auc_score(y_test, y_pred)
    })

    ConfusionMatrixDisplay.from_estimator(
    modelo, X_test, y_test,
    display_labels=['Sem Doença', 'Com Doença'],
    cmap='Blues')
    plt.title(f'Matriz de Confusão — {nome}', fontsize=14, fontweight='bold')
    plt.xlabel('Valor Predito')
    plt.ylabel('Valor Real')
    plt.show()

# %%
# Tabela comparativa
df_resultados = pd.DataFrame(resultados)
df_resultados = df_resultados.sort_values('F1-Score', ascending=False)
print(df_resultados.to_string(index=False))
# Out:
#              Modelo  Acurácia  Precisão   Recall  F1-Score  ROC-AUC
#                 SVM     0.985  0.983051 0.991453  0.987234 0.983678
#            AdaBoost     0.980  0.982906 0.982906  0.982906 0.979405
#             XGBoost     0.970  0.966387 0.982906  0.974576 0.967357
#      SGD Classifier     0.965  0.958333 0.982906  0.970464 0.961333
# Logistic Regression     0.965  0.966102 0.974359  0.970213 0.963083
#       Decision Tree     0.960  0.957983 0.974359  0.966102 0.957059

# %% [markdown]
# ### Conclusão
#
# O modelo **SVM** obteve o melhor desempenho geral, com F1-Score
# de 0.987 e Recall de 0.991 — identificando corretamente 99.1%
# dos pacientes com doença cardiovascular.
#
# Em problemas de diagnóstico médico, o Recall é a métrica mais
# crítica, pois um falso negativo — paciente doente classificado
# como saudável — representa risco real à vida do paciente.
